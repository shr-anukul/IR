# %% [markdown]
# # STW7071CEM (Information Retrieval) Assignment
#
# Task 1:
#
# Create a vertical search engine comparable to Google Scholar, but specialized in retrieving just papers/books published by a member of Coventry University's Research Centre for Intelligent Healthcare (RCIH):

# %% [markdown]
# ## Package Installations

# %%
# !pip install scrapy
# !pip install requests
# !pip install BeautifulSoup4
# !pip install nltk
# !pip install gensim
# !pip install xgboost
# !pip install pandastable
# Out:
# Requirement already satisfied: scrapy in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (2.9.0)
# Requirement already satisfied: tldextract in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (3.4.4)
# Requirement already satisfied: parsel>=1.5.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (21.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (2.1.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: protego>=0.1.15 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (0.2.1)
# Requirement already satisfied: setuptools in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (58.0.4)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: lxml>=4.3.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (4.6.3)
# Requirement already satisfied: Twisted>=18.9.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: packaging in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (21.0)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: service-identity>=18.1.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: cryptography>=3.4.6 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (3.4.8)
# Requirement already satisfied: cffi>=1.12 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=3.4.6->scrapy) (1.14.6)
# Requirement already satisfied: pycparser in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.20)
# Requirement already satisfied: jmespath>=0.9.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from protego>=0.1.15->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (21.2.0)
# Requirement already satisfied: pyasn1-modules in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: incremental>=21.3.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (4.4.0)
# Requirement already satisfied: Automat>=0.8.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: constantly>=15.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: idna>=2.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from hyperlink>=17.1.1->Twisted>=18.9.0->scrapy) (3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from packaging->scrapy) (3.0.4)
# Requirement already satisfied: requests>=2.1.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from tldextract->scrapy) (2.26.0)
# Requirement already satisfied: filelock>=3.0.8 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from tldextract->scrapy) (3.3.1)
# Requirement already satisfied: requests-file>=1.4 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Requirement already satisfied: requests in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: BeautifulSoup4 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from BeautifulSoup4) (2.2.1)
# Requirement already satisfied: nltk in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: click in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: gensim in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.20.3)
# Requirement already satisfied: scipy>=1.7.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.7.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from gensim) (6.3.0)
# Requirement already satisfied: xgboost in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (1.7.6)
# Requirement already satisfied: scipy in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.20.3)
# Requirement already satisfied: pandastable in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (0.13.1)
# Requirement already satisfied: matplotlib>=3.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandastable) (3.4.3)
# Requirement already satisfied: pandas>=1.5 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandastable) (2.0.3)
# Requirement already satisfied: future in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandastable) (0.18.2)
# Requirement already satisfied: numexpr>=2.4 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandastable) (2.7.3)
# Requirement already satisfied: xlrd>=0.9 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandastable) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->pandastable) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->pandastable) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->pandastable) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->pandastable) (1.20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->pandastable) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->pandastable) (8.4.0)
# Requirement already satisfied: six in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.0->pandastable) (1.16.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.5->pandastable) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/kule/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.5->pandastable) (2021.3)

# %% [markdown]
# ## Importing Packages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import datetime
import string
import json
import nltk
nltk.download('omw-1.4');
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package omw-1.4 to /Users/kule/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kule/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /Users/kule/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/kule/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/kule/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 1. Crawler Component

# %%
URL = "https://pureportal.coventry.ac.uk/en/organisations/coventry-university/persons/"
profile_url = "https://pureportal.coventry.ac.uk/en/persons/"

# %%
def maximum_page():
    
    first = requests.get(URL)
    soup = BeautifulSoup(first.text, 'html.parser')
    final_page = soup.select('#main-content > div > section > nav > ul > li:nth-child(12) > a')[0]['href']
    fp = final_page.split('=')[-1]
    return int(fp)
    
mx = maximum_page()
mx
# Out:
# 46

# %% [markdown]
# Instead of crawling all researchers, this web crawler is designed to specifically find researchers who:
#
# 1. Have research publications
# 2. Is a part of Coventry University's Research Centre for Intelligent Healthcare

# %%
def check_department(researcher):
    
    l1 = researcher.find('div', class_='rendering_person_short')
      
    for span in l1.find_all('span'):
        # Check department
        #print(span.text)
        if span.text == str('Centre for Intelligent Healthcare'):
            name = researcher.find('h3', class_='title').find('span').text
            return name
        else:
            pass

def create_csv():
     database = pd.DataFrame(columns=['Title', 'Author', 'Published', 'Link'])
     database.to_csv('database.csv')
    
def update_csv(database):
    current_data = pd.read_csv(database, index_col="Unnamed: 0")
    return current_data        

def enter_each_researchers_publication(researcher, url, df):

    new_url = url + str(researcher).replace(' ','-').lower() + '/publications/'
    page = requests.get(new_url)
    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find(id="main-content")
    papers = results.find_all("li", class_="list-result-item")

    for paper in papers:
        title = paper.find('h3', class_='title')
        if title is not None:
            title_span = title.find('span')
            title_text = title_span.text if title_span is not None else "N/A"
        else:
            title_text = "N/A"

        author = paper.find('a', class_='link person')
        print(author)
        if author == None or author == 'None':
            continue
        else:
            author_span = author.find('span')
            author_text = author_span.text if author_span is not None else "N/A"

        date = paper.find('span', class_="date")
        date_text = date.text if date is not None else "N/A"

        link = paper.find('h3', class_='title')
        link_href = link.find('a', href=True)['href'] if link is not None else "N/A"
        print(link_href)

        # Read the existing database.csv file
        opening = pd.read_csv('database.csv', index_col="Unnamed: 0")

        # Create a new DataFrame with the data to be appended
        new_row = pd.DataFrame({'Title': [title.text],
                                'Author': [author.text],
                                'Published': [date.text],
                                'Link': [link_href]})

        # Concatenate the existing DataFrame and the new row DataFrame
        opening = pd.concat([opening, new_row], ignore_index=True)

        # Save the updated DataFrame to database.csv
        opening.to_csv('database.csv')

# %%
def scrape(mx):
    df = update_csv('database.csv')
    i=0
    while True:
    
        if i > 17:
            break
            
        if i>0:
            url = URL + '?page=' + str(i)
        else:
            url = URL
    
        i = i+1
        # scraping starts here
        page = requests.get(url)
        soup = BeautifulSoup(page.content, "html.parser")
        results = soup.find(id="main-content")
        researchers = results.find_all("li", class_="grid-result-item")

        for researcher in researchers:
            # Check if researcher has any papers
            check = researcher.find('div', class_='stacked-trend-widget')
            if check:
                name = check_department(researcher)
                if name is None:
                    pass
                else:
                    enter_each_researchers_publication(name, profile_url, df)

# %%
create_csv()
update_csv(database='database.csv') #create_csv

# %time scrape(mx)
# Out:
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/deep-learning-identification-of-coronary-artery-disease-from-bila
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/usability-and-preliminary-efficacy-of-an-ai-driven-platform-suppo-2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/assessing-hemodynamics-from-the-photoplethysmogram-to-gain-insigh
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/book-pitch-article-on-photoplethysmography-technology-signal-anal
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications
# None
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/a-serious-game-for-children-with-attention-deficit-hyperactivity-
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/bts-conference-using-the-japanese-kj-ho-method-as-a-qualitative-c
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/design-and-evaluation-of-a-pervasive-coaching-and-gamification-pl
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/tts-conference-using-the-japanese-kj-ho-method-as-a-qualitative-c
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/ian-dunwell" rel="Person"><span>Dunwell, I.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/promoting-healthy-adolescent-lifestyles-through-serious-games-ena
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/behavioral-outcome-effects-of-serious-gaming-as-an-adjunct-to-tre-2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/let-them-play-experiences-in-the-wild-with-a-gamification-and-coa
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/pergamon-a-serious-game-and-digital-coaching-platform-supporting-
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/ian-dunwell" rel="Person"><span>Dunwell, I.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/translating-open-data-to-educational-minigames-2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/development-and-user-satisfaction-of-plan-it-commander-a-serious--2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/adhd-is-a-risk-factor-for-overweight-and-obesity-in-children
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/behavior-problems-in-relation-to-sustained-selective-attention-sk
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/dania-dahmash" rel="Person"><span>Dahmash, D.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/needs-of-parents-and-carers-of-children-and-young-people-with-men
# CPU times: user 3.3 s, sys: 143 ms, total: 3.44 s
# Wall time: 1min 6s

# %%
sample_db = pd.read_csv('database.csv').rename(columns={'Unnamed: 0':'SN'})
sample_db
print(f'{sample_db.shape[0]} records were scraped')
# Out:
# 123 records were scraped

# %% [markdown]
# # 2. Indexing

# %%
scraped_db = pd.read_csv('database.csv').rename(columns={'Unnamed: 0':'SN'}).reset_index(drop=True)
scraped_db.head()
# scraped_db = pd.read_csv('database.csv', index_col=0)
# Out:
#    SN                                              Title     Author  \
# 0   0  Deep learning identification of coronary arter...  Allen, J.
# 1   1  Usability and preliminary efficacy of an AI-dr...    Bul, K.
# 2   2  Assessing hemodynamics from the photoplethysmo...  Allen, J.
# 3   3  Book Pitch article on Photoplethysmography: te...  Allen, J.
# 4   4  Ethnic Disparities in Publicly-available Pulse...  Allen, J.
#
#      Published                                               Link
# 0  1 Sept 2023  https://pureportal.coventry.ac.uk/en/publicati...
# 1  16 Apr 2023  https://pureportal.coventry.ac.uk/en/publicati...
# 2   1 Apr 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 3  25 May 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 4  27 May 2022  https://pureportal.coventry.ac.uk/en/publicati...

# %%
sample_db.head(7)
#ids = scraped_db["Title"]
#scraped_db[ids.isin(ids[ids.duplicated()])]
# Out:
#    SN                                              Title     Author  \
# 0   0  Deep learning identification of coronary arter...  Allen, J.
# 1   1  Usability and preliminary efficacy of an AI-dr...    Bul, K.
# 2   2  Assessing hemodynamics from the photoplethysmo...  Allen, J.
# 3   3  Book Pitch article on Photoplethysmography: te...  Allen, J.
# 4   4  Ethnic Disparities in Publicly-available Pulse...  Allen, J.
# 5   5  Novel pulse device for diagnosis of peripheral...  Allen, J.
# 6   6  Prospective assessment of the diagnostic accur...  Allen, J.
#
#      Published                                               Link
# 0  1 Sept 2023  https://pureportal.coventry.ac.uk/en/publicati...
# 1  16 Apr 2023  https://pureportal.coventry.ac.uk/en/publicati...
# 2   1 Apr 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 3  25 May 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 4  27 May 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 5  24 Oct 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 6  18 Aug 2022  https://pureportal.coventry.ac.uk/en/publicati...

# %%
single_row = scraped_db.loc[1,:].copy()
single_row
# Out:
# SN                                                           1
# Title        Usability and preliminary efficacy of an AI-dr...
# Author                                                 Bul, K.
# Published                                          16 Apr 2023
# Link         https://pureportal.coventry.ac.uk/en/publicati...
# Name: 1, dtype: object

# %% [markdown]
# ## 2.1 Preprocessing Text

# %%
# Removing stop words
sw = stopwords.words("english")
lemmatizer = WordNetLemmatizer()

def tp1(txt):
    txt = txt.lower()   # Make lowercase
    txt = txt.translate(str.maketrans('','',string.punctuation))   # Remove punctuation marks
    txt = lematize(txt)
    return txt


def fwpt(word):
    tag = pos_tag([word])[0][1][0].upper()
    hash_tag = {"V": wordnet.VERB, "R": wordnet.ADV,"N": wordnet.NOUN,"J": wordnet.ADJ}         
    return hash_tag.get(tag, wordnet.NOUN)

def lematize(text):
        tkns = nltk.word_tokenize(text)
        ax = ""
        for each in tkns:
            if each not in sw:
                ax += lemmatizer.lemmatize(each, fwpt(each)) + " "
        return ax

# %%
# Sample title
single_row['Title']
# Out:
# 'Usability and preliminary efficacy of an AI-driven platform supporting dietary management in diabetes: A mixed-method study'

# %%
# Demonstration of lowercase and punctuation removal
tp1(single_row['Title'])
# Out:
# 'usability preliminary efficacy aidriven platform support dietary management diabetes mixedmethod study '

# %%
# Demonstration of lematization

lematize(tp1(single_row['Title']))
#lematize(single_row['Title'])
# Out:
# 'usability preliminary efficacy aidriven platform support dietary management diabetes mixedmethod study '

# %% [markdown]
# ### 2.1.1 Preprocess entire dataframe

# %%
processed_db = scraped_db.copy()

def preprocess_df(df):
    df.Title = df.Title.apply(tp1)
    df.Author = df.Author.str.lower()
    df = df.drop(columns=['Author','Published'], axis=1)
    return df
    
preprocess_df(processed_db)
processed_db.head()
# Out:
#    SN                                              Title     Author  \
# 0   0  deep learn identification coronary artery dise...  allen, j.
# 1   1  usability preliminary efficacy aidriven platfo...    bul, k.
# 2   2  assess hemodynamics photoplethysmogram gain in...  allen, j.
# 3   3  book pitch article photoplethysmography techno...  allen, j.
# 4   4  ethnic disparity publiclyavailable pulse oxime...  allen, j.
#
#      Published                                               Link
# 0  1 Sept 2023  https://pureportal.coventry.ac.uk/en/publicati...
# 1  16 Apr 2023  https://pureportal.coventry.ac.uk/en/publicati...
# 2   1 Apr 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 3  25 May 2022  https://pureportal.coventry.ac.uk/en/publicati...
# 4  27 May 2022  https://pureportal.coventry.ac.uk/en/publicati...

# %% [markdown]
# ## 2.2 Index Construction

# %%
single = processed_db.loc[0,:].copy()
print(single)
indexing_trial = {}

words = single.Title.split()
SN = single.SN
word = words[0]
example = {word: [SN]}

print('=====================================================================')
print('Sample index')
print(example)
# Out:
# SN                                                           0
# Title        deep learn identification coronary artery dise...
# Author                                               allen, j.
# Published                                          1 Sept 2023
# Link         https://pureportal.coventry.ac.uk/en/publicati...
# Name: 0, dtype: object
# =====================================================================
# Sample index
# {'deep': [0]}

# %%
## Indexer Function
def apply_index(inputs, index):
    words = inputs.Title.split()
    SN = int(inputs.SN)
    for word in words:
        if word in index.keys():
            if SN not in index[word]:
                index[word].append(SN)
        else:
            index[word] = [SN]
    return index

indx = apply_index(inputs=single, index= {})
#print(indx)

# %%
def full_index(df, index):
    for x in range(len(df)):
        inpt = df.loc[x,:]
        ind = apply_index(inputs=inpt, index=index)
    return ind

def construct_index(df, index):
    queue = preprocess_df(df)
    ind = full_index(df=queue, index=index)
    return ind

indexed = full_index(processed_db, 
                     index = {})


indexes = construct_index(df=scraped_db, 
                          index = {})

# %%
with open('indexes.json', 'w') as new_f:
    json.dump(indexes, new_f, sort_keys=True, indent=4)
    
with open('indexes.json', 'r') as file:
    data = json.load(file)

def index_2(df, x_path):
    if len(df) > 0:
        with open(x_path, 'r') as file:
            prior_index = json.load(file)
        new_index = construct_index(df = df, index = prior_index)
        with open(x_path, 'w') as new_f:
            json.dump(new_index, new_f, sort_keys=True, indent=4)

# %%
len(data)
# Out:
# 612

# %%
data
# Out:
# {'185': [52],
#  '21st': [94],
#  '3rs': [80],
#  '3′utr': [52],
#  '7': [84],
#  'aankomende': [106],
#  'abnormality': [31],
#  'acceptance': [98],
#  'accord': [59],
#  'accuracy': [6, 20],
#  'across': [107],
#  'activation': [64],
#  'active': [49],
#  'adaptive': [61],
#  'address': [111, 113],
#  'adhd': [119, 120],
#  'adjunct': [115],
#  'adolescence': [100],
#  'adolescent': [99, 101, 107, 114],
#  'adult': [39, 77, 83, 85, 94, 99],
#  'advance': [21],
#  'age': [2, 19, 51, 54, 62, 63, 77, 79, 91, 93],
#  'ageassociated': [59, 96],
#  'agerelated': [22, 90],
#  'aidriven': [1, 7, 103, 104],
#  'al': [105],
#  'amplitude': [41],
#  'analysis': [3, 13, 41, 42, 44, 55, 56, 77, 102],
#  'animal': [69],
#  'anklebrachial': [33],
#  'antigrippes': [78],
#  'anxiety': [102],
#  'application': [3, 13, 14, 99],
#  'apply': [44],
#  'approach': [26, 54, 114],
#  'appropriate': [50],
#  'arterial': [5, 8, 9, 20, 33, 34, 38, 40, 41, 42, 46],
#  'artery': [0, 6],
#  'article': [3],
#  'as': [105],
#  'assay': [85],
#  'assess': [2],
#  'assessment': [6, 12, 15, 23, 30, 39, 43, 45, 47],
#  'associate': [37, 52],
#  'association': [101],
#  'atrophy': [96],
#  'attend': [28],
#  'attention': [110, 121],
#  'attentiondeficithyperactivity': [115],
#  'autistic': [102],
#  'automate': [76],
#  'autonomic': [12],
#  'avalanche': [75],
#  'aviremic': [64],
#  'aware': [57],
#  'barrier': [56, 84],
#  'base': [9, 67],
#  'bcell': [93],
#  'behavior': [107, 121],
#  'behavioral': [115],
#  'benefit': [110],
#  'best': [66, 100],
#  'beyond': [54],
#  'bilateral': [0],
#  'biomarkers': [62],
#  'blood': [24, 30, 72, 76, 85],
#  'board': [109],
#  'body': [11],
#  'book': [3],
#  'breathing': [35],
#  'breed': [59],
#  'bts': [111],
#  'burden': [53, 86],
#  'canine': [52],
#  'capillaroscopy': [31],
#  'capillary': [47],
#  'card': [72],
#  'care': [6, 32, 34, 40],
#  'carers': [122],
#  'casecontrol': [20],
#  'cd34': [68],
#  'cd8': [69],
#  'ce': [74],
#  'cell': [49, 51, 60, 68, 73, 86],
#  'cellmediated': [91],
#  'cellular': [63],
#  'century': [94],
#  'cerebellar': [49],
#  'challenge': [18, 30, 97],
#  'challenged': [69],
#  'change': [22, 35],
#  'characteristic': [41],
#  'chez': [78],
#  'chikungunya': [53, 57],
#  'child': [110, 115, 119, 120, 121, 122],
#  'choice': [54],
#  'classification': [8, 9],
#  'claudication': [17],
#  'clavicular': [67],
#  'clinic': [28, 66],
#  'clinical': [23, 25, 40],
#  'clinician': [111, 113],
#  'cluster': [44],
#  'coach': [112, 116, 117],
#  'codesign': [107],
#  'collection': [29],
#  'colour': [10],
#  'come': [75],
#  'commander': [119],
#  'commission': [32],
#  'communicate': [38],
#  'comparator': [39],
#  'compare': [46],
#  'comparison': [47, 76],
#  'composition': [43],
#  'comprehensive': [77],
#  'concept': [38],
#  'concern': [111, 113],
#  'conference': [111, 113],
#  'consultancy': [108],
#  'control': [25, 94, 115],
#  'coronary': [0],
#  'correction': [80],
#  'corumination': [101],
#  'creative': [111, 113],
#  'cross': [84],
#  'cuffless': [24],
#  'culture': [60],
#  'currently': [58],
#  'data': [25, 118],
#  'database': [4, 19],
#  'db': [76],
#  'de': [78, 105],
#  'deacetylase': [60],
#  'decline': [59],
#  'deep': [0, 9],
#  'deficit': [110],
#  'definition': [11],
#  'delay': [35],
#  'delivery': [96],
#  'demonstrate': [42],
#  'depression': [102],
#  'depressive': [100],
#  'dermoscopy': [47],
#  'design': [112],
#  'detect': [31, 46],
#  'detection': [9, 26, 38],
#  'develop': [28],
#  'development': [36, 84, 108, 119],
#  'device': [5, 40, 48, 55, 56, 67],
#  'diabetes': [1, 7, 103, 104, 112, 116],
#  'diabetic': [25, 28, 48],
#  'diagnosis': [5, 6, 33, 34, 40],
#  'diagnostic': [6],
#  'dietary': [1, 7, 103, 104],
#  'different': [11],
#  'differentiation': [68],
#  'differs': [59],
#  'difficulty': [122],
#  'digital': [108, 117],
#  'discretechoice': [40],
#  'disease': [0, 5, 6, 8, 9, 15, 20, 33, 34, 38, 40, 41, 46, 86, 90],
#  'disentangle': [100],
#  'disorder': [49, 98, 110, 115],
#  'disparity': [4],
#  'disposable': [37],
#  'distress': [101],
#  'diverse': [19],
#  'dna': [76],
#  'dog': [51, 52, 59],
#  'dose': [69],
#  'dry': [72, 76, 85],
#  'duplex': [8],
#  'dyadic': [100],
#  'eat': [98],
#  'economic': [46],
#  'edinburgh': [17],
#  'educational': [118],
#  'effect': [61, 96, 100, 115],
#  'effectiveness': [55, 56, 77, 87, 91],
#  'efficacité': [78],
#  'efficacy': [1, 7, 103, 104],
#  'ehealth': [99],
#  'elderly': [50, 65, 66, 71, 89, 97],
#  'electrocardiogram': [23, 35],
#  'element': [37],
#  'emotional': [101],
#  'en': [106],
#  'enable': [68],
#  'enact': [114],
#  'encode': [38],
#  'endusers': [55],
#  'epidemiological': [53],
#  'estimate': [40, 85],
#  'ethnic': [4],
#  'europe': [107],
#  'evaluation': [112],
#  'everincreasing': [79],
#  'evidence': [77],
#  'examine': [31],
#  'experience': [33, 87, 98, 116],
#  'experiment': [40],
#  'experimental': [86],
#  'expert': [21],
#  'exploitation': [108],
#  'exploration': [10],
#  'extreme': [93],
#  'factor': [120],
#  'feasibility': [107],
#  'feature': [11, 23],
#  'filter': [11],
#  'filteringinduced': [11],
#  'finger': [0, 31],
#  'firstever': [23],
#  'fluorescence': [43],
#  'focus': [29],
#  'fontan': [39],
#  'foot': [25, 28, 45, 48],
#  'frailty': [90],
#  'frequency': [12],
#  'friend': [100, 101],
#  'function': [12, 50, 86],
#  'gain': [2],
#  'game': [98, 109, 110, 114, 115, 117, 119],
#  'gamification': [112, 116],
#  'general': [17, 20],
#  'geriatrician': [57],
#  'geriatricspecific': [53],
#  'gids': [106],
#  'grade': [8],
#  'group': [39],
#  'health': [32, 107, 108, 109, 122],
#  'healthcare': [117],
#  'healthy': [45, 114],
#  'heart': [42],
#  'hebt': [105],
#  'hemodynamics': [2],
#  'herd': [79],
#  'hhv6': [49],
#  'high': [28, 64],
#  'highrisk': [25],
#  'hiv2': [64],
#  'ho': [111, 113],
#  'host': [58],
#  'housing': [37],
#  'human': [68, 86],
#  'hyperactivity': [110],
#  'hypertension': [23, 26],
#  'identification': [0],
#  'identify': [17],
#  'ii': [56],
#  'il7r': [52],
#  'image': [28, 29, 45, 48],
#  'immune': [50, 63, 64, 71, 88],
#  'immunity': [61, 79, 89, 91],
#  'immunological': [90],
#  'immunomodulating': [61],
#  'immunorejuvenation': [95],
#  'immunosenescence': [73, 79, 80, 83, 90],
#  'immunosenesence': [81],
#  'immunotherapy': [81],
#  'implementation': [32],
#  'implication': [83],
#  'importance': [11],
#  'important': [70],
#  'improve': [26, 99, 107],
#  'increase': [42, 51],
#  'index': [33],
#  'individual': [87, 91, 92, 100],
#  'induces': [60],
#  'infection': [49, 53, 57, 58, 64, 70],
#  'infectious': [86],
#  'influence': [52],
#  'influenza': [69, 77, 91, 94],
#  'influenzavaccine': [87],
#  'infrared': [25],
#  'inhibition': [60],
#  'innate': [61],
#  'innovative': [27, 32, 41, 42],
#  'insight': [2],
#  'interfilter': [72],
#  'interleukin': [84],
#  'interleukin7': [95],
#  'interval': [35],
#  'intervention': [50, 107],
#  'intestinal': [84],
#  'intra': [72],
#  'irregular': [27],
#  'isrctn13301188': [5],
#  'iterative': [107],
#  'jamais': [74],
#  'japanese': [111, 113],
#  'je': [105],
#  'kidney': [111, 113],
#  'kinetics': [64, 69],
#  'kj': [111, 113],
#  'knowhow': [21],
#  'knowledge': [21],
#  'la': [78],
#  'labrador': [52],
#  'le': [74],
#  'learn': [0, 9, 87],
#  'learnt': [108],
#  'lesson': [108],
#  'let': [116],
#  'level': [100],
#  'lifestyle': [114],
#  'light': [18],
#  'limmunosénescence': [82],
#  'literature': [109],
#  'load': [64],
#  'longevity': [59],
#  'look': [54],
#  'low': [12],
#  'lymphocyte': [60, 69],
#  'main': [90],
#  'management': [1, 7, 34, 103, 104],
#  'manual': [76],
#  'many': [31],
#  'markage': [62],
#  'maternal': [84],
#  'maze': [98],
#  'measure': [11, 22, 72, 76],
#  'measurement': [6, 10, 36, 42],
#  'medical': [48],
#  'medicine': [18, 29],
#  'meeting': [55],
#  'mental': [122],
#  'metaanalysis': [109],
#  'method': [14, 44, 111, 113],
#  'microrna': [52],
#  'microvascular': [39],
#  'middelbare': [105],
#  'milk': [84],
#  'minigames': [118],
#  'mixed': [60],
#  'mixedmethod': [1, 7, 103, 104],
#  'mobile': [107],
#  'model': [46, 68, 86],
#  'moderate': [101],
#  'moderately': [121],
#  'modulates': [84],
#  'monitoring': [24, 53, 67],
#  'mood': [49],
#  'motion': [67],
#  'multicentre': [25],
#  'multidisciplinary': [108, 114],
#  'multimodal': [26],
#  'multisite': [6, 22, 30, 33, 35, 41, 42],
#  'naar': [105],
#  'nailfold': [31, 47],
#  'naive': [85],
#  'natural': [86],
#  'need': [19, 53, 55, 79, 111, 113, 122],
#  'negotiate': [32],
#  'network': [102],
#  'neuropathy': [28],
#  'noise': [44],
#  'noninvasive': [40],
#  'non‐autistic': [102],
#  'notepad': [5],
#  'novel': [5, 40, 43, 44, 45],
#  'nurse': [33],
#  'nutritional': [86],
#  'obesity': [120],
#  'obesityrelated': [107],
#  'objective': [10],
#  'occurs': [51],
#  'offspring': [84],
#  'old': [54, 69, 77, 87, 92, 94],
#  'open': [118],
#  'opportunity': [18],
#  'optic': [18],
#  'optical': [39, 43],
#  'optimize': [94],
#  'outcome': [99, 115],
#  'output': [52, 59, 92],
#  'overweight': [120],
#  'oximeter': [19],
#  'oximetry': [4],
#  'oxygen': [39],
#  'oxygenation': [43],
#  'pad': [17],
#  'paediatric': [42],
#  'palliation': [39],
#  'paper': [72],
#  'parameter': [86],
#  'parent': [122],
#  'pathogenesis': [90],
#  'pathology': [64],
#  'pathway': [32, 63],
#  'patient': [33, 43, 98, 111, 112, 113, 116, 117],
#  'people': [28, 54, 102, 122],
#  'perceive': [100],
#  'perfusion': [39],
#  'pergamon': [117],
#  'peripheral': [5, 6, 8, 9, 15, 20, 33, 34, 38, 40, 41, 46],
#  'personal': [100],
#  'personne': [78],
#  'perturbation': [51],
#  'pervasive': [112],
#  'phenomenon': [10],
#  'phone': [107],
#  'photoplethysmogram': [2],
#  'photoplethysmography': [0,
#   3,
#   6,
#   9,
#   11,
#   12,
#   13,
#   14,
#   15,
#   16,
#   22,
#   24,
#   27,
#   30,
#   33,
#   35,
#   38,
#   41,
#   42,
#   44],
#  'photoplethysmographybased': [26],
#  'pilot': [10, 39, 43, 85, 98],
#  'pitch': [3],
#  'pivotal': [64],
#  'planit': [119],
#  'platform': [1, 7, 103, 104, 112, 117],
#  'play': [116],
#  'played': [91],
#  'podiatric': [28],
#  'polymorphism': [52],
#  'pool': [85],
#  'population': [79],
#  'posttranscriptional': [52],
#  'power': [18],
#  'ppg': [14, 21],
#  'ppgsynth': [27],
#  'practice': [17, 20, 66],
#  'practitioner': [40],
#  'praktijk': [106],
#  'preference': [33, 40],
#  'preliminary': [1, 7, 103, 104],
#  'pressure': [24, 30, 33],
#  'preterm': [121],
#  'prevent': [70],
#  'prevention': [25, 48],
#  'primary': [6, 32, 34, 40],
#  'problem': [111, 113, 121],
#  'processing': [16],
#  'professional': [106, 117],
#  'programme': [83],
#  'promote': [114],
#  'proof': [38],
#  'proofofconcept': [0, 9],
#  'prospective': [6],
#  'protection': [64, 94],
#  'protocol': [122],
#  'provoque': [74],
#  'publiclyavailable': [4],
#  'pulse': [4, 5, 6, 11, 19, 22, 35, 38, 41],
#  'purification': [76],
#  'purkinje': [49],
#  'qpcr': [76],
#  'qualitative': [33, 34, 55, 56, 111, 113],
#  'quality': [21],
#  'quantify': [35, 41],
#  'questionnaire': [17],
#  'qui': [74],
#  'randomize': [115],
#  'rate': [36],
#  'ratio': [72],
#  'raynauds': [10],
#  'real': [85],
#  'recent': [36],
#  'receptor': [51],
#  'recipient': [42],
#  'recommend': [65],
#  'recommendation': [30],
#  'reduction': [44],
#  'regeneration': [63],
#  'register': [20],
#  'regular': [27],
#  'regulation': [52],
#  'regulatory': [60],
#  'relation': [121],
#  'reliability': [17, 45],
#  'renal': [99],
#  'repertoire': [51],
#  'replacement': [80],
#  'reporting': [8],
#  'reproducibility': [72],
#  'reprogramming': [80],
#  'research': [108],
#  'researcher': [21],
#  'resistance': [58],
#  'respiratory': [36, 67],
#  'response': [61, 69, 93],
#  'responsiveness': [66],
#  'restoration': [80],
#  'restore': [50],
#  'rethink': [79],
#  'retriever': [52],
#  'reversal': [96],
#  'reverse': [73],
#  'review': [2, 23, 46, 99, 109, 122],
#  'risetime': [22],
#  'risk': [28, 120],
#  'role': [64, 89, 90, 91, 101, 102],
#  'rr': [35],
#  'sample': [72, 76, 85],
#  'satisfaction': [119],
#  'saturation': [39],
#  'sauronsnous': [74],
#  'schedule': [79],
#  'school': [105],
#  'sclerosis': [43],
#  'seasonal': [86],
#  'selective': [121],
#  'senescence': [71, 88],
#  'sense': [0],
#  'sensor': [37],
#  'serious': [98, 110, 114, 115, 117, 119],
#  'shift': [11],
#  'side': [96],
#  'signal': [3, 13, 16, 21, 44, 63],
#  'simple': [38, 68],
#  'singleblind': [25],
#  'singlesite': [24],
#  'sirt1': [60],
#  'site': [11],
#  'skill': [121],
#  'skin': [10],
#  'slowpaced': [35],
#  'snow': [75],
#  'sociaal': [106],
#  'solution': [108],
#  'solve': [111, 113],
#  'specific': [54],
#  'spectrophotometry': [39, 43],
#  'spectroscopy': [43],
#  'spot': [72, 76, 85],
#  'standardise': [8],
#  'standardization': [11],
#  'start': [75],
#  'stateoftheart': [14],
#  'status': [58],
#  'stiffness': [42],
#  'strike': [19],
#  'student': [21],
#  'study': [0, 1, 7, 9, 10, 20, 33, 34, 38, 39, 43, 85, 98, 103, 104, 107],
#  'successful': [32],
#  'suicidal': [102],
#  'supplementation': [60],
#  'support': [1, 7, 100, 101, 103, 104, 117],
#  'sustain': [121],
#  'symptom': [100],
#  'symptomatic': [17],
#  'synthesis': [16],
#  'synthesize': [27],
#  'system': [8, 45, 68, 116],
#  'systematic': [46, 53, 99, 109, 122],
#  'systemic': [43],
#  'tcell': [64, 84, 85],
#  'technique': [38, 46, 111, 113],
#  'technology': [3, 13, 30, 32, 36],
#  'telehealthcare': [55, 56],
#  'temperature': [10, 45],
#  'theory‐driven': [102],
#  'thermal': [28, 29, 45, 48],
#  'thermography': [25],
#  'thought': [102],
#  'thymic': [52, 59, 86, 92, 96],
#  'thymus': [89],
#  'time': [11],
#  'timepcr': [85],
#  'timing': [41],
#  'tissue': [39, 43],
#  'toolbox': [27],
#  'towards': [68],
#  'trace': [92],
#  'transfuse': [69],
#  'translate': [61, 118],
#  'translation': [21],
#  'transplant': [42, 99, 111, 113],
#  'treatment': [96, 111, 113, 115],
#  'trec': [72, 76],
#  'trial': [25, 115],
#  'tt': [113],
#  'u': [57],
#  'uk': [20],
#  'ulcer': [25, 28],
#  'ulceration': [48],
#  'ultrasound': [8],
#  'understood': [58],
#  'undertake': [68],
#  'uptake': [56],
#  'usability': [1, 7, 103, 104],
#  'use': [23, 39, 40, 43, 46, 111, 113],
#  'user': [98, 119],
#  'vaccination': [54, 65, 71, 83, 93, 97],
#  'vaccine': [61, 66, 77, 79, 87, 91],
#  'vaccins': [78],
#  'validation': [8],
#  'variability': [12, 28, 41],
#  'vascagenet': [2],
#  'vascular': [2, 15, 18, 39],
#  'versus': [64],
#  'viability': [43],
#  'videocapillaroscopy': [47],
#  'vieillissement': [74],
#  'viral': [64],
#  'virus': [53, 57],
#  'visit': [28],
#  'vitamin': [58, 61, 70],
#  'voor': [106],
#  'waveform': [27],
#  'welzijn': [106],
#  'werk': [106],
#  'wetenschap': [106],
#  'whole': [85],
#  'wild': [116],
#  'young': [69, 85, 99, 111, 112, 113, 116, 122],
#  'zinc': [60],
#  'zorg': [106],
#  'âgée': [78],
#  '’': [33, 111, 113],
#  '“': [119],
#  '”': [119]}

# %% [markdown]
# ## 3.  Query Processor

# %%
def demonstrate_query_processing():
    sample = input('Enter Search Terms: ')
    processed_query = tp1(sample)
    #print(f'User Search Query: {sample}')
    print(f'Processed Search Query: {processed_query}')
    return processed_query
    
#demonstrate_query_processing()

# %% [markdown]
# ### 3.1.  Split Query into individual terms

# %%
def split_query(terms):
    each = tp1(terms)
    return each.split()

dqp = demonstrate_query_processing()
dqp
print(f'Split Query: {split_query(dqp)}')
# Out:
# Enter Search Terms:
# Processed Search Query:
# Split Query: []

# %% [markdown]
# ### 3.2.  Boolean Functionalities

# %%
def union(lists):
    union = list(set.union(*map(set, lists)))
    union.sort()
    return union

def intersection(lists):
    intersect = list(set.intersection(*map(set, lists)))
    intersect.sort()
    return intersect

# %% [markdown]
# ### 3.3. Search Engine Function

# %%
def vertical_search_engine(df, query, index=indexes):
    query_split = split_query(query)
    retrieved = []
    for word in query_split:
        if word in index.keys():
            retrieved.append(index[word])
            
            
    # Ranked Retrieval
    if len(retrieved)>0:
        high_rank_result = intersection(retrieved)
        low_rank_result = union(retrieved) 
        c = [x for x in low_rank_result if x not in high_rank_result]      
        high_rank_result.extend(c)
        result = high_rank_result
        
        final_output = df[df.SN.isin(result)].reset_index(drop=True)
    
        # Return result in order of Intersection ----> Union
        dummy = pd.Series(result, name = 'SN').to_frame()
        result = pd.merge(dummy, final_output, on='SN', how = 'left')
        
    else:
        result = 'No result found'
    
    return result

# %%
def test_search_engine():
    xtest = scraped_db.copy()
    query = input("Enter your search query: ")
    return vertical_search_engine(xtest, query, indexed)
    
test_search_engine()
# Out:
# Enter your search query:
# 'No result found'

# %%
def final_engine(results):
    if type(results) != 'list':
        return results
        #print(results)
    else:
        for i in range(len(results)):
            printout = results.loc[i, :]

# %%
scraped_db['Author'].iloc[24]
# Out:
# 'zheng, d.'

# %%
final_engine(test_search_engine())
# Out:
# Enter your search query:
# 'No result found'

# %% [markdown]
# ## 4. Schedule Crawler for every week
#
# To demonstrate a weekly scheduled crawling, the following parameters are defined:
#
# * `interval` : Represents number of days in reality. In this code, it represents only seconds for demonstration

# %%
days = 0
interval = 7
while days <= 1:
    scrape(mx)
    print(f"Crawled at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f'Next crawl scheduled after {interval} days')
    time.sleep(interval)
    days = days + 1
# Out:
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/deep-learning-identification-of-coronary-artery-disease-from-bila
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/usability-and-preliminary-efficacy-of-an-ai-driven-platform-suppo-2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/assessing-hemodynamics-from-the-photoplethysmogram-to-gain-insigh
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/book-pitch-article-on-photoplethysmography-technology-signal-anal
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/ethnic-disparities-in-publicly-available-pulse-oximetry-databases
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/novel-pulse-device-for-diagnosis-of-peripheral-arterial-disease-n
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/prospective-assessment-of-the-diagnostic-accuracy-of-multi-site-p
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/usability-and-preliminary-efficacy-of-an-ai-driven-platform-suppo
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/validation-of-a-standardised-duplex-ultrasound-classification-sys
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/deep-learning-based-photoplethysmography-classification-for-perip
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/explorations-in-skin-temperature-and-objective-skin-colour-measur
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/haipeng-liu" rel="Person"><span>Liu, H.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/filtering-induced-time-shifts-in-photoplethysmography-pulse-featu
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/low-frequency-variability-in-photoplethysmography-and-autonomic-f
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J. (ed.)</span></a>
# https://pureportal.coventry.ac.uk/en/publications/photoplethysmography-technology-signal-analysis-and-applications
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/photoplethysmography-ppg-state-of-the-art-methods-and-application
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/photoplethysmography-for-the-assessment-of-peripheral-vascular-di
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/photoplethysmography-signal-processing-and-synthesis
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/reliability-of-the-edinburgh-claudication-questionnaire-for-ident
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/the-power-of-light-in-medicine-challenges-and-opportunities-in-va
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/the-striking-need-for-age-diverse-pulse-oximeter-databases
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/accuracy-of-peripheral-arterial-disease-registers-in-uk-general-p
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/dingchang-zheng-2" rel="Person"><span>Zheng, D.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/advancing-ppg-signal-quality-and-know-how-through-knowledge-trans
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/age-related-changes-in-pulse-risetime-measured-by-multi-site-phot
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/assessment-of-hypertension-using-clinical-electrocardiogram-featu
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/dingchang-zheng-2" rel="Person"><span>Zheng, D.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/cuffless-single-site-photoplethysmography-for-blood-pressure-moni
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/infrared-thermography-and-ulcer-prevention-in-the-high-risk-diabe
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/dingchang-zheng-2" rel="Person"><span>Zheng, D.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/multimodal-photoplethysmography-based-approaches-for-improved-det
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/ppgsynth-an-innovative-toolbox-for-synthesizing-regular-and-irreg
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/between-visit-variability-of-thermal-imaging-of-feet-in-people-at
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/john-allen" rel="Person"><span>Allen, J.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/focus-collection-on-thermal-imaging-in-medicine
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/dingchang-zheng-2" rel="Person"><span>Zheng, D.</span></a>
# https://pureportal.coventry.ac.uk/en/publications
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/a-serious-game-for-children-with-attention-deficit-hyperactivity-
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/bts-conference-using-the-japanese-kj-ho-method-as-a-qualitative-c
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/design-and-evaluation-of-a-pervasive-coaching-and-gamification-pl
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/tts-conference-using-the-japanese-kj-ho-method-as-a-qualitative-c
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/ian-dunwell" rel="Person"><span>Dunwell, I.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/promoting-healthy-adolescent-lifestyles-through-serious-games-ena
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/behavioral-outcome-effects-of-serious-gaming-as-an-adjunct-to-tre-2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/let-them-play-experiences-in-the-wild-with-a-gamification-and-coa
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/pergamon-a-serious-game-and-digital-coaching-platform-supporting-
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/ian-dunwell" rel="Person"><span>Dunwell, I.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/translating-open-data-to-educational-minigames-2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/development-and-user-satisfaction-of-plan-it-commander-a-serious--2
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/adhd-is-a-risk-factor-for-overweight-and-obesity-in-children
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/kim-bul" rel="Person"><span>Bul, K.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/behavior-problems-in-relation-to-sustained-selective-attention-sk
# <a class="link person" href="https://pureportal.coventry.ac.uk/en/persons/dania-dahmash" rel="Person"><span>Dahmash, D.</span></a>
# https://pureportal.coventry.ac.uk/en/publications/needs-of-parents-and-carers-of-children-and-young-people-with-men
# Crawled at 2023-07-10 10:20:29
# Next crawl scheduled after 7 days

# %% [markdown]
# # 5. GUI

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk 
from tkinter import scrolledtext
from pandastable import Table, TableModel
from contextlib import suppress
import warnings
warnings.filterwarnings('ignore')



image1 = Image.open('coventry-university-logo.png')
resized_image1 = image1.resize((250,200), Image.ANTIALIAS)

def new_gui(image1):
    window = Tk()
    window.configure(bg='#F0F0F0')
    window.title("CU Search Engine")
    window.geometry('900x700')
    
    lbl = Label(window, text="Search Engine",bg="#F0F0F0", font=("Calibri", 30), padx=5, pady=5)
    lbl.grid(column=1, row=1)
    
    lbl2 = Label(window, text="Enter the search query here", bg="#F0F0F0",font=("Calibri", 15), padx=5, pady=5)
    lbl2.grid(column=0, row=2)
    
    
    img = ImageTk.PhotoImage(image1)
    
    lbl3 = Label(image=img)
    lbl3.image = img
    lbl3.grid(column=3, row=5, padx=5, pady=5)
    
    
    
    query = Entry(window,width=80)
    query.grid(column=1, row=2,  padx=5, pady=5)
    
    results = Canvas(window, height=40, width=350)
    results.grid(column=1, row=3, padx=5, pady=5)
    
    # Entry
    def getInputBoxValue():
        userInput = query.get()
        return userInput

    
    # Button
    def clicked():
        search()
        #pass
        
    def no_result():
        messagebox.showwarning("Warning", "No results found. Please try different search terms")
        
    
    def search():
        xtest = scraped_db.copy()
        q = query.get()
        f = Frame(window)
        df = vertical_search_engine(xtest, q, indexed)
        if type(df) == str:
            no_result()
        else:
            pt = Table(results)
            try:
                table = pt = Table(results, dataframe=df)
                pt.show()
            except AttributeError:
                pass
            
    def close_window():
        if messagebox.askokcancel("Quit", "Quit Programme?"):
            window.destroy()
        
    
    btn = Button(window, text="Search",bg="#F0F0F0", command=clicked)
    btn.grid(column=2, row=2)
    
    

    window.protocol("WM_DELETE_WINDOW", close_window)       
    window.mainloop()

# %%
new_gui(resized_image1)
